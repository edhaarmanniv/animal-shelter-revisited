# %%
import pandas as pd
import requests
import os

from socrata_token import token_string

# %%
# intial request
intakes_url = "https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm"
intakes_api = "https://data.austintexas.gov/resource/wter-evkm.json"
header = {"X-App-Token":f"{token_string}"}
offset=0
payload = {"$offset":offset}

intake_r = requests.get(intakes_api, headers=header, params=payload)
intake_status = intake_r.status_code
intakes_df = pd.DataFrame(intake_r.json())

while intake_status == 200:
    offset += 1
    intake_r = requests.get(intakes_url, headers=header, params=payload)
    intake_status = intake_r.status_code
    intakes_df = pd.concat([intakes_df, pd.DataFrame(intake_r.json())], ignore_index=True)
    print(f"offset={offset}, status={intake_status}")

intakes_df
# Out:
# offset=1, status=200
# offset=2, status=200
# offset=3, status=200
# offset=4, status=200
# offset=5, status=200
# offset=6, status=200
# offset=7, status=200
# offset=8, status=200
# offset=9, status=200
# offset=10, status=200
# offset=11, status=200
# offset=12, status=200
# offset=13, status=200
# offset=14, status=200
# offset=15, status=200
# offset=16, status=200
# offset=17, status=200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-634c2b14891b> in <module>
#      11 while intake_status == 200:
#      12     offset += 1
# ---> 13     intake_r = requests.get(intakes_url, headers=header, params=payload)
#      14     intake_status = intake_r.status_code
#      15     intakes_df = pd.concat([intakes_df, pd.DataFrame(intake_r.json())], ignore_index=True)
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     974         # Force connect early to allow us to validate the connection.
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#     978         if not conn.is_verified:
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\connection.py in connect(self)
#     306     def connect(self):
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#     310
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#     162
#
# ~\.virtualenvs\animal-shelter-revisited-e1DvYyWC\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %%
# intial request
intakes_url = "https://data.austintexas.gov/resource/wter-evkm.json"
header = {"X-App-Token":f"{token_string}"}
offset=1
payload = {"$offset":offset}

intake_r = requests.get(intakes_url, headers=header, params=payload)
intake_status = intake_r.status_code
intakes_df = pd.DataFrame(intake_r.json())


offset = 119
intake_r = requests.get(intakes_url, headers=header, params=payload)
intakes_df = pd.concat([intakes_df, pd.DataFrame(intake_r.json())], ignore_index=True)

intakes_df
# Out:
#      animal_id           name                 datetime  \
# 0      A796845         *Shuri  2020-06-06T10:39:00.000
# 1      A818352            NaN  2020-06-06T10:17:00.000
# 2      A818346            NaN  2020-06-06T07:41:00.000
# 3      A818347            NaN  2020-06-06T07:41:00.000
# 4      A818345         Leslie  2020-06-06T07:41:00.000
# ...        ...            ...                      ...
# 1995   A815853         Jackie  2020-03-28T09:59:00.000
# 1996   A815858       Mr Buddy  2020-03-28T09:59:00.000
# 1997   A815856  Meredith Gray  2020-03-28T09:59:00.000
# 1998   A783844          Rocky  2020-03-28T09:08:00.000
# 1999   A815848            NaN  2020-03-27T18:54:00.000
#
#                     datetime2                            found_location  \
# 0     2020-06-06T10:39:00.000  4700 East Riverside Drive in Austin (TX)
# 1     2020-06-06T10:17:00.000                 Highway 71 in Austin (TX)
# 2     2020-06-06T07:41:00.000                               Austin (TX)
# 3     2020-06-06T07:41:00.000                               Austin (TX)
# 4     2020-06-06T07:41:00.000                               Austin (TX)
# ...                       ...                                       ...
# 1995  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 1996  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 1997  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 1998  2020-03-28T09:08:00.000          Rpbert T Martinez in Austin (TX)
# 1999  2020-03-27T18:54:00.000              2815 Manor Rd in Austin (TX)
#
#      intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0          Stray             Sick         Cat   Spayed Female         7 years
# 1          Stray           Normal         Dog     Intact Male         2 years
# 2          Stray           Normal         Dog     Intact Male         1 month
# 3          Stray           Normal         Cat   Intact Female         1 month
# 4          Stray             Sick         Dog         Unknown        3 months
# ...          ...              ...         ...             ...             ...
# 1995       Stray           Normal         Dog   Spayed Female         8 years
# 1996       Stray           Normal         Dog   Neutered Male         8 years
# 1997       Stray           Normal         Dog   Spayed Female          1 year
# 1998       Stray           Normal         Dog   Neutered Male         2 years
# 1999    Wildlife           Normal       Other         Unknown          1 year
#
#                           breed             color
# 0            Domestic Shorthair             Black
# 1           Chihuahua Shorthair       Black/Brown
# 2                Siberian Husky             White
# 3        Domestic Shorthair Mix            Torbie
# 4                     Boxer Mix       Brown/Black
# ...                         ...               ...
# 1995              Catahoula Mix  Blue Merle/White
# 1996               Basset Hound    Black/Tricolor
# 1997  Australian Cattle Dog Mix       Brown/White
# 1998               Pit Bull Mix       Brown/White
# 1999                        Bat             Brown
#
# [2000 rows x 12 columns]

# %%
intakes_df.sort_values(by = ["animal_id"]).to_csv("intakes_duplicates.csv")

# %%
intakes_url = "https://data.austintexas.gov/resource/wter-evkm.json?"

header = {"X-App-Token":f"{token_string}"}
soql_params = {"$offset":1}

intake_response = r.get(intakes_url, headers=header, params=soql_params)
print(intake_response.url)
# Out:
# https://data.austintexas.gov/resource/wter-evkm.json?%24offset=1

# %%
intakes_df = pd.DataFrame(intake_response.json())
intakes_df
# Out:
#     animal_id           name                 datetime  \
# 0     A796845         *Shuri  2020-06-06T10:39:00.000
# 1     A818352            NaN  2020-06-06T10:17:00.000
# 2     A818346            NaN  2020-06-06T07:41:00.000
# 3     A818347            NaN  2020-06-06T07:41:00.000
# 4     A818345         Leslie  2020-06-06T07:41:00.000
# ..        ...            ...                      ...
# 995   A815853         Jackie  2020-03-28T09:59:00.000
# 996   A815858       Mr Buddy  2020-03-28T09:59:00.000
# 997   A815856  Meredith Gray  2020-03-28T09:59:00.000
# 998   A783844          Rocky  2020-03-28T09:08:00.000
# 999   A815848            NaN  2020-03-27T18:54:00.000
#
#                    datetime2                            found_location  \
# 0    2020-06-06T10:39:00.000  4700 East Riverside Drive in Austin (TX)
# 1    2020-06-06T10:17:00.000                 Highway 71 in Austin (TX)
# 2    2020-06-06T07:41:00.000                               Austin (TX)
# 3    2020-06-06T07:41:00.000                               Austin (TX)
# 4    2020-06-06T07:41:00.000                               Austin (TX)
# ..                       ...                                       ...
# 995  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 996  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 997  2020-03-28T09:59:00.000        10940 Research Blvd in Austin (TX)
# 998  2020-03-28T09:08:00.000          Rpbert T Martinez in Austin (TX)
# 999  2020-03-27T18:54:00.000              2815 Manor Rd in Austin (TX)
#
#     intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0         Stray             Sick         Cat   Spayed Female         7 years
# 1         Stray           Normal         Dog     Intact Male         2 years
# 2         Stray           Normal         Dog     Intact Male         1 month
# 3         Stray           Normal         Cat   Intact Female         1 month
# 4         Stray             Sick         Dog         Unknown        3 months
# ..          ...              ...         ...             ...             ...
# 995       Stray           Normal         Dog   Spayed Female         8 years
# 996       Stray           Normal         Dog   Neutered Male         8 years
# 997       Stray           Normal         Dog   Spayed Female          1 year
# 998       Stray           Normal         Dog   Neutered Male         2 years
# 999    Wildlife           Normal       Other         Unknown          1 year
#
#                          breed             color
# 0           Domestic Shorthair             Black
# 1          Chihuahua Shorthair       Black/Brown
# 2               Siberian Husky             White
# 3       Domestic Shorthair Mix            Torbie
# 4                    Boxer Mix       Brown/Black
# ..                         ...               ...
# 995              Catahoula Mix  Blue Merle/White
# 996               Basset Hound    Black/Tricolor
# 997  Australian Cattle Dog Mix       Brown/White
# 998               Pit Bull Mix       Brown/White
# 999                        Bat             Brown
#
# [1000 rows x 12 columns]

# %%
from pprint import pprint
type(intake_response.status_code)
# Out:
# int
